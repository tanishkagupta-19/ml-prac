# %% [markdown]
# # 🔍 Four Types of Analytics
#
#
#
# ## 1. 📊 Descriptive Analytics — *What happened?*
# - Summarizes past data into understandable insights.
# - **Example:** Sales reports, website traffic trends.
#
#
#
# ## 2. 🕵️ Diagnostic Analytics — *Why did it happen?*
# - Digs deeper into data to find causes of events.
# - **Example:** Root cause analysis of declining sales.
#
#
#
# ## 3. 🔮 Predictive Analytics — *What will happen?*
# - Uses historical data + ML/statistics to forecast future outcomes.
# - **Example:** Predicting customer churn or demand forecasting.
#
#
#
# ## 4. 🎯 Prescriptive Analytics — *What should we do about it?*
# - Suggests actions or strategies based on predictions.
# - **Example:** Recommending marketing campaigns, dynamic pricing.
#
#
#
# ### 📌 Quick Summary
#
# | Type          | Question Answered     | Example Use Case                     |
# |---------------|-----------------------|---------------------------------------|
# | Descriptive   | What happened?        | Sales reports, web traffic trends     |
# | Diagnostic    | Why did it happen?    | Root cause of sales decline           |
# | Predictive    | What will happen?     | Demand forecasting, churn prediction  |
# | Prescriptive  | What should we do?    | Marketing campaigns, dynamic pricing  |
