# %%
import pandas as pd

# %%
print(" DataFrame (2D table - rows & columns)".upper())
# Out:
#  DATAFRAME (2D TABLE - ROWS & COLUMNS)

# %% [markdown]
# SERIES (1D DATA)

# %%
data=pd.Series([10,20,30])  # series of 1D data
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
#  DATAFRAME (2D TABLE - ROWS & COLUMNS)

# %%
data={'Name':["Bob","Alex"], 'Age':[23,45]}
df=pd.DataFrame(data)
print(df)
# Out:
#    Name  Age
# 0   Bob   23
# 1  Alex   45
