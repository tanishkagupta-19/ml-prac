# %% [markdown]
# # 📊 Mean vs Median vs Mode in Machine Learning
#
# ## 1. ➗ Mean (Average)
# - **Definition:** Sum of all values ÷ number of values.
# - **Use in ML:**
#   - Feature scaling & normalization (centering data around mean).
#   - Imputation → Fill missing numeric values with the **mean** (only if no outliers).
#   - Used in algorithms like **Linear Regression** (minimizes Mean Squared Error).
# - **Example:**
#   Dataset: [2, 3, 5, 10]
#   Mean = (2+3+5+10) / 4 = **5**
#
# ## 2. 📍 Median (Middle Value)
# - **Definition:** Middle value when data is sorted.
# - If even count → average of two middle values.
# - Use **Median** if data has outliers.
# - **Use in ML:**
#   - Better for skewed data (e.g., income distribution).
#   - Imputation → Fill missing values with **median** to avoid distortion by outliers.
#   - Used in **Robust Scaler** (scales data based on median & IQR).
# - **Example:**
#   Dataset: [2, 3, 5, 10]
#   Median = (3 + 5) / 2 = **4**
#
# ## 3. 🔁 Mode (Most Frequent Value)
# - **Definition:** Value that occurs most frequently.
# - Can be unimodal, multimodal, or no mode.
# - **Use in ML:**
#   - Handling **categorical features** (most frequent imputation).
#   - Mode encoding for categorical variables.
#   - Helps in identifying class imbalance in classification problems.
# - **Example:**
#   Dataset: [2, 3, 3, 5, 10]
#   Mode = **3**
#
# ### 📌 Quick Comparison (in ML)
#
# | Measure | What it Represents   | ML Use Case |
# |---------|----------------------|-------------|
# | **Mean**    | Arithmetic average | Normalization, regression, numeric imputation |
# | **Median**  | Middle value       | Outlier-robust imputation, robust scaling     |
# | **Mode**    | Most frequent      | Categorical imputation, imbalance detection   |
#
# ### 🎯 Example with Outliers (ML Context)
# Dataset: [2, 3, 4, 5, 100]
#
# - **Mean:** 22.8 → Bad for imputation (distorted by outlier).
# - **Median:** 4 → Better for imputation.
# - **Mode:** None → Not useful here.
#
# 👉 In ML preprocessing:
# - Use **Mean** if data is normal.
# - Use **Median** if data has outliers.
# - Use **Mode** for categorical features.
